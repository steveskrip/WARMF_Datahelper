# %%
f = open('ntdrain.orc','r')

# %%
f
# Out:
# <open file 'ntdrain.orc', mode 'r' at 0x03867860>

# %%
f_lines = f.readlines()

# %%
f_lines
# Out:
# ['VERSION        3\n',
#  'Latitude:    39.525 Longitude:  -119.705 NORTH TRUCKEE DRAIN                            \n',
#  '           25MTEMP   MH      MNH4    MAL     MCA     MMG     MK      MNA     MSO4    MNO3    MCL     MPO4    MALK    MOACD   MSIO4   MCOLI   MDO     MBOD    MTPO4   MTON    MTKN    MTNH4   MTOC    MTSS    MTDS    \n',
#  '03101984 0000    11.5    8.08   0.012    -999    -999    -999    -999    -999    -999    0.15    -999    -999    -999    -999    -999     600    -999     0.8     0.1    -999    -999    -999    -999    -999     24021NEV-1  310513          \n',
#  '07111984 0000       8    8.09   0.023    -999    -999    -999    -999    -999    -999    0.21    -999    -999    -999    -999    -999     260    -999    -999     0.1    -999    -999    -999    -999    -999     30021NEV-1  310513          \n',
# ...

# %%
f_lines[0]
# Out:
# 'VERSION        3\n'

# %%
f_lines[2].split(' ')
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '25MTEMP',
#  '',
#  '',
#  'MH',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'MNH4',
#  '',
#  '',
#  '',
#  'MAL',
#  '',
#  '',
#  '',
#  '',
#  'MCA',
#  '',
#  '',
#  '',
#  '',
#  'MMG',
#  '',
#  '',
#  '',
#  '',
#  'MK',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'MNA',
#  '',
#  '',
#  '',
#  '',
#  'MSO4',
#  '',
#  '',
#  '',
#  'MNO3',
#  '',
#  '',
#  '',
#  'MCL',
#  '',
#  '',
#  '',
#  '',
#  'MPO4',
#  '',
#  '',
#  '',
#  'MALK',
#  '',
#  '',
#  '',
#  'MOACD',
#  '',
#  '',
#  'MSIO4',
#  '',
#  '',
#  'MCOLI',
#  '',
#  '',
#  'MDO',
#  '',
#  '',
#  '',
#  '',
#  'MBOD',
#  '',
#  '',
#  '',
#  'MTPO4',
#  '',
#  '',
#  'MTON',
#  '',
#  '',
#  '',
#  'MTKN',
#  '',
#  '',
#  '',
#  'MTNH4',
#  '',
#  '',
#  'MTOC',
#  '',
#  '',
#  '',
#  'MTSS',
#  '',
#  '',
#  '',
#  'MTDS',
#  '',
#  '',
#  '',
#  '\n']

# %%
f_lines[2][13:21].strip()
# Out:
# 'MTEMP'

# %%
import csv

# %%
float('14.12')
# Out:
# 14.12

# %%
headline = f_lines[2]
headline_list=[]
pointer = 13

for i, col in enumerate(f_lines[2]):
    if i <= pointer:
        pass
    else:
        start = pointer
        end = pointer+8
        headline_list.append(headline[start:end].strip())
        pointer = pointer + 8
        print headline_list
# Out:
# ['MTEMP']
# ['MTEMP', 'MH']
# ['MTEMP', 'MH', 'MNH4']
# ['MTEMP', 'MH', 'MNH4', 'MAL']
# ['MTEMP', 'MH', 'MNH4', 'MAL', 'MCA']
# ['MTEMP', 'MH', 'MNH4', 'MAL', 'MCA', 'MMG']
# ['MTEMP', 'MH', 'MNH4', 'MAL', 'MCA', 'MMG', 'MK']
# ['MTEMP', 'MH', 'MNH4', 'MAL', 'MCA', 'MMG', 'MK', 'MNA']
# ['MTEMP', 'MH', 'MNH4', 'MAL', 'MCA', 'MMG', 'MK', 'MNA', 'MSO4']
# ['MTEMP', 'MH', 'MNH4', 'MAL', 'MCA', 'MMG', 'MK', 'MNA', 'MSO4', 'MNO3']
# ['MTEMP', 'MH', 'MNH4', 'MAL', 'MCA', 'MMG', 'MK', 'MNA', 'MSO4', 'MNO3', 'MCL']
# ['MTEMP', 'MH', 'MNH4', 'MAL', 'MCA', 'MMG', 'MK', 'MNA', 'MSO4', 'MNO3', 'MCL', 'MPO4']
# ['MTEMP', 'MH', 'MNH4', 'MAL', 'MCA', 'MMG', 'MK', 'MNA', 'MSO4', 'MNO3', 'MCL', 'MPO4', 'MALK']
# ['MTEMP', 'MH', 'MNH4', 'MAL', 'MCA', 'MMG', 'MK', 'MNA', 'MSO4', 'MNO3', 'MCL', 'MPO4', 'MALK', 'MOACD']
# ['MTEMP', 'MH', 'MNH4', 'MAL', 'MCA', 'MMG', 'MK', 'MNA', 'MSO4', 'MNO3', 'MCL', 'MPO4', 'MALK', 'MOACD', 'MSIO4']
# ...

# %%
from datetime import datetime

# %%
datetime.strptime('03101984','%d%m%Y')
# Out:
# datetime.datetime(1984, 10, 3, 0, 0)

# %%
f_lines
# Out:
# ['VERSION        3\n',
#  'Latitude:    39.525 Longitude:  -119.705 NORTH TRUCKEE DRAIN                            \n',
#  '           25MTEMP   MH      MNH4    MAL     MCA     MMG     MK      MNA     MSO4    MNO3    MCL     MPO4    MALK    MOACD   MSIO4   MCOLI   MDO     MBOD    MTPO4   MTON    MTKN    MTNH4   MTOC    MTSS    MTDS    \n',
#  '03101984 0000    11.5    8.08   0.012    -999    -999    -999    -999    -999    -999    0.15    -999    -999    -999    -999    -999     600    -999     0.8     0.1    -999    -999    -999    -999    -999     24021NEV-1  310513          \n',
#  '07111984 0000       8    8.09   0.023    -999    -999    -999    -999    -999    -999    0.21    -999    -999    -999    -999    -999     260    -999    -999     0.1    -999    -999    -999    -999    -999     30021NEV-1  310513          \n',
# ...

# %%
f_lines[6]
# Out:
# '09011985 0000     4.5    8.04   0.026    -999    39.4    16.2    3.93    36.1    19.7    0.23    -999    -999    -999    -999    -999      40    -999    -999     0.1    -999    -999    -999    -999    -999     30221NEV-1  310513          \n'

# %%
f = open(outfile)
reader = csv.reader(f)

# %%
reader.next()
# Out:
# ["['VERSION        3\\n', 'Latitude:    39.525 Longitude:  -119.705 NORTH TRUCKEE DRAIN                            \\n']"]

# %%
f.close
# Out:
# <function close>

# %%
reader.next()
# Out:
# ['           25']

# %%
reader.next()
reader.line_num
# Out:
# 9L

# %%
f = open('test1.txt','w')

# %%
f.write(['234','sdfsd','234'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-633f170af067> in <module>()
# ----> 1 f.write(['234','sdfsd','234'])
#
# TypeError: expected a character buffer object

# %%
f.write('234')

# %%
f.write('\n')

# %%
f.close()

# %%
from dateutil.parser import parse

# %%
parse('4/7/2010 0:00')
# Out:
# datetime.datetime(2010, 4, 7, 0, 0)

# %%
x = ['3','4','5']

# %%
len(x)
# Out:
# 3

# %%
x[3]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-68-ed224ad0520d> in <module>()
# ----> 1 x[3]
#
# IndexError: list index out of range

# %%
# %run WARMF_ORCtoWARMF.py
# Out:
# 0
# case 0
# 1
# case 1
# 2
# case 2
# 3
# case 3
# 4
# case 4
# 5
# 3/6/1985 0:00
# 6
# 4/3/1985 0:00
# 7
# 4/22/1985 0:00
# 8
# 4/22/1985 0:00
# 9
# 5/1/1985 0:00
# 10
# 5/13/1985 0:00
# 11
# 6/5/1985 0:00
# 12
# 6/18/1985 0:00
# 13
# 7/10/1985 0:00
# 14
# 7/15/1985 0:00
# 15
# 8/7/1985 0:00
# 16
# 8/12/1985 0:00
# 17
# 8/12/1985 0:00
# 18
# 9/4/1985 0:00
# 19
# 9/19/1985 0:00
# 20
# 9/19/1985 0:00
# 21
# 10/2/1985 0:00
# 22
# 10/29/1985 0:00
# 23
# 10/29/1985 0:00
# 24
# 11/6/1985 0:00
# 25
# 11/19/1985 0:00
# 26
# 11/19/1985 0:00
# 27
# 12/4/1985 0:00
# 28
# 12/4/1985 0:00
# 29
# 12/17/1985 0:00
# 30
# 12/17/1985 0:00
# 31
# 1/8/1986 0:00
# 32
# 1/23/1986 0:00
# 33
# 1/23/1986 0:00
# 34
# 2/5/1986 0:00
# 35
# 2/24/1986 0:00
# 36
# 2/24/1986 0:00
# 37
# 3/5/1986 0:00
# 38
# 3/11/1986 0:00
# 39
# 3/11/1986 0:00
# 40
# 4/2/1986 0:00
# 41
# 4/15/1986 0:00
# 42
# 4/15/1986 0:00
# 43
# 5/7/1986 0:00
# 44
# 5/12/1986 0:00
# 45
# 5/12/1986 0:00
# 46
# 6/4/1986 0:00
# 47
# 6/16/1986 0:00
# ...

# %%
# %run WARMF_ORCtoWARMF.py
# Out:
# 0
# case 0
# 1
# case 1
# 2
# case 2
# 3
# case 3
# 4
# case 4
# 5
# 3/6/1985 0:00
# 6
# 4/3/1985 0:00
# 7
# 4/22/1985 0:00
# 8
# 4/22/1985 0:00
# 9
# 5/1/1985 0:00
# 10
# 5/13/1985 0:00
# 11
# 6/5/1985 0:00
# 12
# 6/18/1985 0:00
# 13
# 7/10/1985 0:00
# 14
# 7/15/1985 0:00
# 15
# 8/7/1985 0:00
# 16
# 8/12/1985 0:00
# 17
# 8/12/1985 0:00
# 18
# 9/4/1985 0:00
# 19
# 9/19/1985 0:00
# 20
# 9/19/1985 0:00
# 21
# 10/2/1985 0:00
# 22
# 10/29/1985 0:00
# 23
# 10/29/1985 0:00
# 24
# 11/6/1985 0:00
# 25
# 11/19/1985 0:00
# 26
# 11/19/1985 0:00
# 27
# 12/4/1985 0:00
# 28
# 12/4/1985 0:00
# 29
# 12/17/1985 0:00
# 30
# 12/17/1985 0:00
# 31
# 1/8/1986 0:00
# 32
# 1/23/1986 0:00
# 33
# 1/23/1986 0:00
# 34
# 2/5/1986 0:00
# 35
# 2/24/1986 0:00
# 36
# 2/24/1986 0:00
# 37
# 3/5/1986 0:00
# 38
# 3/11/1986 0:00
# 39
# 3/11/1986 0:00
# 40
# 4/2/1986 0:00
# 41
# 4/15/1986 0:00
# 42
# 4/15/1986 0:00
# 43
# 5/7/1986 0:00
# 44
# 5/12/1986 0:00
# 45
# 5/12/1986 0:00
# 46
# 6/4/1986 0:00
# 47
# 6/16/1986 0:00
# ...
